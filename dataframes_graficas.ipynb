# %%
import pandas as pd
import numpy as np
pd.options.display.max_columns=None

# %%
df_adalab = pd.read_csv('archivos_resultantes/archivo_unificado_limpio.csv')
df_adalab.drop('Unnamed: 0',axis=1,inplace=True)
df_adalab.head()
# Out:
#    id_survey  time    age gender    country            studies  \
# 0          0   910  50-54    Man      India  Bachelor’s degree
# 1          1   784  50-54    Man  Indonesia    Master’s degree
# 2          2   924  22-24    Man   Pakistan    Master’s degree
# 3          3   575  45-49    Man     Mexico    Doctoral degree
# 4          4   781  45-49    Man      India    Doctoral degree
#
#                   position years_programming preferred_language  \
# 0                    Other            Senior             Python
# 1  Program/Project Manager         Architect             Python
# 2        Software Engineer            Junior             Python
# 3       Research Scientist         Architect             Python
# 4                    Other            Junior             Python
#
#            computing_platform times_use_tpu years_use_ml  \
# 0                    A laptop     2-5 times         5-10
# 1  A cloud computing platform         Never          < 1
# 2                    A laptop         Never      Not use
# 3  A cloud computing platform           >25         5-10
# 4  A cloud computing platform         Never        10-20
#
#                     industry company_size da_employees    company_ml  \
# 0  Manufacturing/Fabrication        Small          3-4            No
# 1  Manufacturing/Fabrication        Large          1-2     Exploring
# 2        Academics/Education        Large            0    Don´t know
# 3        Academics/Education        Large            0    Don´t know
# 4        Academics/Education        Small          5-9  For insights
#
#      year_salary investment_ml  main_bd  main_bi  \
# 0  25,000-29,999       100-999  unknown  unknown
# 1  60,000-69,999             0  unknown  unknown
# 2          0-999             0    MySQL  unknown
# 3  30,000-39,999             0  unknown  unknown
# 4  30,000-39,999    1000-9,999  unknown  unknown
#
#                           main_da programming_languages  \
# 0  Local development environments             Python, R
# 1   Advanced statistical software     SQL, C, C++, Java
# 2      Basic statistical software     Python, C++, Java
# 3  Local development environments                Python
# 4  Local development environments     Python, C, MATLAB
#
#                                 ide           hardware  \
# 0                       Vim / Emacs  Google Cloud TPUs
# 1        Notepad++,Jupyter Notebook                NaN
# 2  PyCharm ,Jupyter Notebook, Other              Other
# 3           Spyder,Jupyter Notebook        NVIDIA GPUs
# 4   Spyder,MATLAB ,Jupyter Notebook                NaN
#
#                                        visualization  \
# 0  Matplotlib ,Seaborn ,Ggplot / ggplot2 ,Shiny ,...
# 1                                         Matplotlib
# 2                                         Matplotlib
# 3                                         Matplotlib
# 4              Matplotlib ,Seaborn ,Ggplot / ggplot2
#
#                            ml_tools  \
# 0  Scikit-learn , TensorFlow ,Caret
# 1                      Scikit-learn
# 2                           unknown
# 3  Scikit-learn , TensorFlow ,Keras
# 4   Scikit-learn ,PyTorch ,LightGBM
#
#                                         ml_algorithm  \
# 0  Linear or Logistic Regression, Decision Trees ...
# 1  Linear or Logistic Regression, Decision Trees ...
# 2                                            unknown
# 3  Dense Neural Networks , Convolutional Neural N...
# 4  Linear or Logistic Regression, Decision Trees ...
#
#                                               duties             bd_a  \
# 0  None of these activities are an important part...       PostgreSQL
# 1  Build and/or run the data infrastructure that ...          unknown
# 2  None of these activities are an important part...  MySQL , MongoDB
# 3  Do research that advances the state of the art...          unknown
# 4  Analyze and understand data to influence produ...              NaN
#
#                    bi best_cloud_services                         notebooks  \
# 0                 NaN             unknown                   Colab Notebooks
# 1             unknown             unknown  Kaggle Notebooks,Colab Notebooks
# 2                 NaN             unknown                  Kaggle Notebooks
# 3             unknown             unknown                   Colab Notebooks
# 4  Microsoft Power BI             unknown              Google Cloud Datalab
#
#                                      computer_vision                      nlp  \
# 0                  General purpose image/video tools  Word embeddings/vectors
# 1                                            unknown                  unknown
# 2                                            unknown                  unknown
# 3  General purpose image/video tools ,Image segme...                  unknown
# 4                                            unknown                  unknown
#
#        cloud_platforms_a                   cloud_product_a  \
# 0  Google Cloud Platform       Google Cloud Compute Engine
# 1                unknown                           unknown
# 2                unknown                           unknown
# 3                unknown                           unknown
# 4        Microsoft Azure  Microsoft Azure Virtual Machines
#
#              data_storage_products_a                  ml_products_a  \
# 0               Google Cloud Storage                      No / None
# 1                            unknown                        unknown
# 2                            unknown                      DataRobot
# 3                            unknown                        unknown
# 4  Microsoft Azure Data Lake Storage  Azure Machine Learning Studio
#
#   automated_ml_tools_a regular_automl_a  ml_experiments_a  \
# 0            No / None          unknown         No / None
# 1              unknown          unknown           unknown
# 2            No / None          unknown         No / None
# 3              unknown          unknown           unknown
# 4            No / None          unknown  Weights & Biases
#
#                            sharing  \
# 0                  GitHub , Kaggle
# 1                          unknown
# 2  I do not share my work publicly
# 3                          unknown
# 4  I do not share my work publicly
#
#                                              courses  \
# 0  Coursera,edX,Kaggle Learn Courses,DataCamp,Uda...
# 1  Kaggle Learn Courses,Cloud-certification progr...
# 2                                           DataCamp
# 3                                       Coursera,edX
# 4                         Kaggle Learn Courses,Udemy
#
#                                                media  \
# 0  Email newsletters ,Kaggle ,YouTube ,Podcasts ,...
# 1                               Journal Publications
# 2                                    Kaggle ,YouTube
# 3               YouTube ,Blogs ,Journal Publications
# 4                               Journal Publications
#
#                               cloud_platforms_b  \
# 0                                       unknown
# 1         Google Cloud Platform  , Oracle Cloud
# 2  Amazon Web Services  , Google Cloud Platform
# 3        Amazon Web Services  , Microsoft Azure
# 4                                       unknown
#
#                                     cloud_products_b data_storage_products_b  \
# 0                                            unknown                 unknown
# 1                        Google Cloud Compute Engine                 unknown
# 2  Microsoft Azure Virtual Machines , Google Clou...                 unknown
# 3  Microsoft Azure Virtual Machines , Google Clou...                 unknown
# 4                                            unknown                 unknown
#
#                                        ml_products_b  \
# 0                                            unknown
# 1                                            unknown
# 2  Azure Machine Learning Studio , Google Cloud V...
# 3                                            unknown
# 4                                            unknown
#
#                                                bd_b  \
# 0                                           unknown
# 1  MySQL ,SQLite ,Oracle Database ,Google Cloud SQL
# 2                        MySQL ,PostgreSQL ,MongoDB
# 3                                           unknown
# 4                                           unknown
#
#                          bi_b       automated_ml_tools_b     regular_automl_b  \
# 0                     unknown                    unknown              unknown
# 1     Google Data Studio,Qlik  Automated model selection  Google Cloud AutoML
# 2  Microsoft Power BI,Tableau  Automated model selection     DataRobot AutoML
# 3                     unknown                    unknown              unknown
# 4                     unknown                    unknown              unknown
#
#   ml_experiments_b
# 0          unknown
# 1          unknown
# 2      TensorBoard
# 3          unknown
# 4          unknown

# %%
df_adalab.isnull().sum()*100/df_adalab.shape[0]
# Out:
# id_survey                   0.000000
# time                        0.000000
# age                         0.000000
# gender                      0.000000
# country                     0.000000
# studies                     0.000000
# position                    0.000000
# years_programming           0.000000
# preferred_language          0.000000
# computing_platform          0.000000
# times_use_tpu               0.000000
# years_use_ml                0.000000
# industry                    0.000000
# company_size                0.000000
# da_employees                0.000000
# company_ml                  0.000000
# year_salary                 0.000000
# investment_ml               0.000000
# main_bd                     0.000000
# main_bi                     0.000000
# main_da                     0.000000
# programming_languages       1.228199
# ide                         2.025180
# hardware                   50.952913
# visualization              13.394679
# ml_tools                    7.376891
# ml_algorithm                5.659724
# duties                      0.000000
# bd_a                        8.843799
# bi                         15.874177
# best_cloud_services         0.000000
# notebooks                   0.000000
# computer_vision             0.000000
# nlp                         0.000000
# cloud_platforms_a           0.000000
# cloud_product_a             0.000000
# data_storage_products_a     0.000000
# ml_products_a               0.000000
# automated_ml_tools_a        0.000000
# regular_automl_a            0.000000
# ml_experiments_a            0.000000
# sharing                     0.000000
# courses                     0.000000
# media                       0.000000
# cloud_platforms_b           0.000000
# cloud_products_b            0.000000
# data_storage_products_b     0.000000
# ml_products_b               0.000000
# bd_b                        0.000000
# bi_b                        0.000000
# automated_ml_tools_b        0.000000
# regular_automl_b            0.000000
# ml_experiments_b            0.000000
# dtype: float64

# %%
df_adalab.head(2)
# Out:
#    id_survey  time    age gender    country            studies  \
# 0          0   910  50-54    Man      India  Bachelor’s degree
# 1          1   784  50-54    Man  Indonesia    Master’s degree
#
#                   position years_programming preferred_language  \
# 0                    Other            Senior             Python
# 1  Program/Project Manager         Architect             Python
#
#            computing_platform times_use_tpu years_use_ml  \
# 0                    A laptop     2-5 times         5-10
# 1  A cloud computing platform         Never          < 1
#
#                     industry company_size da_employees company_ml  \
# 0  Manufacturing/Fabrication        Small          3-4         No
# 1  Manufacturing/Fabrication        Large          1-2  Exploring
#
#      year_salary investment_ml  main_bd  main_bi  \
# 0  25,000-29,999       100-999  unknown  unknown
# 1  60,000-69,999             0  unknown  unknown
#
#                           main_da programming_languages  \
# 0  Local development environments             Python, R
# 1   Advanced statistical software     SQL, C, C++, Java
#
#                           ide           hardware  \
# 0                 Vim / Emacs  Google Cloud TPUs
# 1  Notepad++,Jupyter Notebook                NaN
#
#                                        visualization  \
# 0  Matplotlib ,Seaborn ,Ggplot / ggplot2 ,Shiny ,...
# 1                                         Matplotlib
#
#                            ml_tools  \
# 0  Scikit-learn , TensorFlow ,Caret
# 1                      Scikit-learn
#
#                                         ml_algorithm  \
# 0  Linear or Logistic Regression, Decision Trees ...
# 1  Linear or Logistic Regression, Decision Trees ...
#
#                                               duties        bd_a       bi  \
# 0  None of these activities are an important part...  PostgreSQL      NaN
# 1  Build and/or run the data infrastructure that ...     unknown  unknown
#
#   best_cloud_services                         notebooks  \
# 0             unknown                   Colab Notebooks
# 1             unknown  Kaggle Notebooks,Colab Notebooks
#
#                      computer_vision                      nlp  \
# 0  General purpose image/video tools  Word embeddings/vectors
# 1                            unknown                  unknown
#
#        cloud_platforms_a              cloud_product_a data_storage_products_a  \
# 0  Google Cloud Platform  Google Cloud Compute Engine    Google Cloud Storage
# 1                unknown                      unknown                 unknown
#
#   ml_products_a automated_ml_tools_a regular_automl_a ml_experiments_a  \
# 0     No / None            No / None          unknown        No / None
# 1       unknown              unknown          unknown          unknown
#
#            sharing                                            courses  \
# 0  GitHub , Kaggle  Coursera,edX,Kaggle Learn Courses,DataCamp,Uda...
# 1          unknown  Kaggle Learn Courses,Cloud-certification progr...
#
#                                                media  \
# 0  Email newsletters ,Kaggle ,YouTube ,Podcasts ,...
# 1                               Journal Publications
#
#                        cloud_platforms_b             cloud_products_b  \
# 0                                unknown                      unknown
# 1  Google Cloud Platform  , Oracle Cloud  Google Cloud Compute Engine
#
#   data_storage_products_b ml_products_b  \
# 0                 unknown       unknown
# 1                 unknown       unknown
#
#                                                bd_b                     bi_b  \
# 0                                           unknown                  unknown
# 1  MySQL ,SQLite ,Oracle Database ,Google Cloud SQL  Google Data Studio,Qlik
#
#         automated_ml_tools_b     regular_automl_b ml_experiments_b
# 0                    unknown              unknown          unknown
# 1  Automated model selection  Google Cloud AutoML          unknown

# %%
df = df_adalab.copy()

# %%
df.head(2)
# Out:
#    id_survey  time    age gender    country            studies  \
# 0          0   910  50-54    Man      India  Bachelor’s degree
# 1          1   784  50-54    Man  Indonesia    Master’s degree
#
#                   position years_programming preferred_language  \
# 0                    Other            Senior             Python
# 1  Program/Project Manager         Architect             Python
#
#            computing_platform times_use_tpu years_use_ml  \
# 0                    A laptop     2-5 times         5-10
# 1  A cloud computing platform         Never          < 1
#
#                     industry company_size da_employees company_ml  \
# 0  Manufacturing/Fabrication        Small          3-4         No
# 1  Manufacturing/Fabrication        Large          1-2  Exploring
#
#      year_salary investment_ml  main_bd  main_bi  \
# 0  25,000-29,999       100-999  unknown  unknown
# 1  60,000-69,999             0  unknown  unknown
#
#                           main_da programming_languages  \
# 0  Local development environments             Python, R
# 1   Advanced statistical software     SQL, C, C++, Java
#
#                           ide           hardware  \
# 0                 Vim / Emacs  Google Cloud TPUs
# 1  Notepad++,Jupyter Notebook                NaN
#
#                                        visualization  \
# 0  Matplotlib ,Seaborn ,Ggplot / ggplot2 ,Shiny ,...
# 1                                         Matplotlib
#
#                            ml_tools  \
# 0  Scikit-learn , TensorFlow ,Caret
# 1                      Scikit-learn
#
#                                         ml_algorithm  \
# 0  Linear or Logistic Regression, Decision Trees ...
# 1  Linear or Logistic Regression, Decision Trees ...
#
#                                               duties        bd_a       bi  \
# 0  None of these activities are an important part...  PostgreSQL      NaN
# 1  Build and/or run the data infrastructure that ...     unknown  unknown
#
#   best_cloud_services                         notebooks  \
# 0             unknown                   Colab Notebooks
# 1             unknown  Kaggle Notebooks,Colab Notebooks
#
#                      computer_vision                      nlp  \
# 0  General purpose image/video tools  Word embeddings/vectors
# 1                            unknown                  unknown
#
#        cloud_platforms_a              cloud_product_a data_storage_products_a  \
# 0  Google Cloud Platform  Google Cloud Compute Engine    Google Cloud Storage
# 1                unknown                      unknown                 unknown
#
#   ml_products_a automated_ml_tools_a regular_automl_a ml_experiments_a  \
# 0     No / None            No / None          unknown        No / None
# 1       unknown              unknown          unknown          unknown
#
#            sharing                                            courses  \
# 0  GitHub , Kaggle  Coursera,edX,Kaggle Learn Courses,DataCamp,Uda...
# 1          unknown  Kaggle Learn Courses,Cloud-certification progr...
#
#                                                media  \
# 0  Email newsletters ,Kaggle ,YouTube ,Podcasts ,...
# 1                               Journal Publications
#
#                        cloud_platforms_b             cloud_products_b  \
# 0                                unknown                      unknown
# 1  Google Cloud Platform  , Oracle Cloud  Google Cloud Compute Engine
#
#   data_storage_products_b ml_products_b  \
# 0                 unknown       unknown
# 1                 unknown       unknown
#
#                                                bd_b                     bi_b  \
# 0                                           unknown                  unknown
# 1  MySQL ,SQLite ,Oracle Database ,Google Cloud SQL  Google Data Studio,Qlik
#
#         automated_ml_tools_b     regular_automl_b ml_experiments_b
# 0                    unknown              unknown          unknown
# 1  Automated model selection  Google Cloud AutoML          unknown

# %%
columnas = ['id_survey','programming_languages', 'ide','hardware', 'visualization','ml_tools','ml_algorithm','bd_a','bi','notebooks','computer_vision','nlp','cloud_platforms_a',
'cloud_product_a','data_storage_products_a','ml_products_a','automated_ml_tools_a','ml_experiments_a','sharing','courses','media','cloud_platforms_b','cloud_products_b', 'ml_products_b','bd_b', 'bi_b', 'automated_ml_tools_b', 'regular_automl_b','ml_experiments_b']

# %%
df_explode = df[columnas]

# %%
df_explode.head(2)
# Out:
#    id_survey programming_languages                         ide  \
# 0          0             Python, R                 Vim / Emacs
# 1          1     SQL, C, C++, Java  Notepad++,Jupyter Notebook
#
#             hardware                                      visualization  \
# 0  Google Cloud TPUs  Matplotlib ,Seaborn ,Ggplot / ggplot2 ,Shiny ,...
# 1                NaN                                         Matplotlib
#
#                            ml_tools  \
# 0  Scikit-learn , TensorFlow ,Caret
# 1                      Scikit-learn
#
#                                         ml_algorithm        bd_a       bi  \
# 0  Linear or Logistic Regression, Decision Trees ...  PostgreSQL      NaN
# 1  Linear or Logistic Regression, Decision Trees ...     unknown  unknown
#
#                           notebooks                    computer_vision  \
# 0                   Colab Notebooks  General purpose image/video tools
# 1  Kaggle Notebooks,Colab Notebooks                            unknown
#
#                        nlp      cloud_platforms_a  \
# 0  Word embeddings/vectors  Google Cloud Platform
# 1                  unknown                unknown
#
#                cloud_product_a data_storage_products_a ml_products_a  \
# 0  Google Cloud Compute Engine    Google Cloud Storage     No / None
# 1                      unknown                 unknown       unknown
#
#   automated_ml_tools_a ml_experiments_a          sharing  \
# 0            No / None        No / None  GitHub , Kaggle
# 1              unknown          unknown          unknown
#
#                                              courses  \
# 0  Coursera,edX,Kaggle Learn Courses,DataCamp,Uda...
# 1  Kaggle Learn Courses,Cloud-certification progr...
#
#                                                media  \
# 0  Email newsletters ,Kaggle ,YouTube ,Podcasts ,...
# 1                               Journal Publications
#
#                        cloud_platforms_b             cloud_products_b  \
# 0                                unknown                      unknown
# 1  Google Cloud Platform  , Oracle Cloud  Google Cloud Compute Engine
#
#   ml_products_b                                              bd_b  \
# 0       unknown                                           unknown
# 1       unknown  MySQL ,SQLite ,Oracle Database ,Google Cloud SQL
#
#                       bi_b       automated_ml_tools_b     regular_automl_b  \
# 0                  unknown                    unknown              unknown
# 1  Google Data Studio,Qlik  Automated model selection  Google Cloud AutoML
#
#   ml_experiments_b
# 0          unknown
# 1          unknown

# %%
for col in columnas[1:]:
    df_explode[col] = df_explode[col].str.split(',')
# Out:
# /var/folders/cf/7kf7s8j17wn53znl0ywm912w0000gp/T/ipykernel_16544/2930975392.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_explode[col] = df_explode[col].str.split(',')

# %%
df_explode.head(2)
# Out:
#    id_survey   programming_languages                            ide  \
# 0          0            [Python,  R]                  [Vim / Emacs]
# 1          1  [SQL,  C,  C++,  Java]  [Notepad++, Jupyter Notebook]
#
#               hardware                                      visualization  \
# 0  [Google Cloud TPUs]  [Matplotlib , Seaborn , Ggplot / ggplot2 , Shi...
# 1                  NaN                                       [Matplotlib]
#
#                                ml_tools  \
# 0  [Scikit-learn ,  TensorFlow , Caret]
# 1                        [Scikit-learn]
#
#                                         ml_algorithm          bd_a         bi  \
# 0  [Linear or Logistic Regression,  Decision Tree...  [PostgreSQL]        NaN
# 1  [Linear or Logistic Regression,  Decision Tree...     [unknown]  [unknown]
#
#                              notebooks                      computer_vision  \
# 0                    [Colab Notebooks]  [General purpose image/video tools]
# 1  [Kaggle Notebooks, Colab Notebooks]                            [unknown]
#
#                          nlp        cloud_platforms_a  \
# 0  [Word embeddings/vectors]  [Google Cloud Platform]
# 1                  [unknown]                [unknown]
#
#                  cloud_product_a data_storage_products_a ml_products_a  \
# 0  [Google Cloud Compute Engine]  [Google Cloud Storage]   [No / None]
# 1                      [unknown]               [unknown]     [unknown]
#
#   automated_ml_tools_a ml_experiments_a             sharing  \
# 0          [No / None]      [No / None]  [GitHub ,  Kaggle]
# 1            [unknown]        [unknown]           [unknown]
#
#                                              courses  \
# 0  [Coursera, edX, Kaggle Learn Courses, DataCamp...
# 1  [Kaggle Learn Courses, Cloud-certification pro...
#
#                                                media  \
# 0  [Email newsletters , Kaggle , YouTube , Podcas...
# 1                             [Journal Publications]
#
#                           cloud_platforms_b               cloud_products_b  \
# 0                                 [unknown]                      [unknown]
# 1  [Google Cloud Platform  ,  Oracle Cloud]  [Google Cloud Compute Engine]
#
#   ml_products_b                                               bd_b  \
# 0     [unknown]                                          [unknown]
# 1     [unknown]  [MySQL , SQLite , Oracle Database , Google Clo...
#
#                          bi_b         automated_ml_tools_b  \
# 0                   [unknown]                    [unknown]
# 1  [Google Data Studio, Qlik]  [Automated model selection]
#
#         regular_automl_b ml_experiments_b
# 0              [unknown]        [unknown]
# 1  [Google Cloud AutoML]        [unknown]

# %%
for col in columnas[1:]:
    df.drop(col,axis=1,inplace=True)

# %%
df.shape
# Out:
# (25973, 25)

# %%
df_explode.shape
# Out:
# (25973, 29)

# %%
df.to_csv('archivos_resultantes/dataframe_graficas.csv')
df_explode.to_csv('archivos_resultantes/dataframe_graficas_explode.csv')
