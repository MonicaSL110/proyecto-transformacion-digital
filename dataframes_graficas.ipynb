# %%
import pandas as pd
import numpy as np
pd.options.display.max_columns=None

# %%
df_adalab = pd.read_csv('archivos_resultantes/archivo_unificado_limpio.csv',index_col=0)

# %%
df_adalab.head(2)
# Out:
#    id_survey  time    age gender    country            studies  \
# 0          0   910  50-54    Man      India  Bachelor’s degree
# 1          1   784  50-54    Man  Indonesia    Master’s degree
#
#                   position years_programming preferred_language  \
# 0                    Other               NaN             Python
# 1  Program/Project Manager               NaN             Python
#
#            computing_platform times_use_tpu years_use_ml  \
# 0                    A laptop     2-5 times         5-10
# 1  A cloud computing platform         Never          < 1
#
#                     industry company_size da_employees company_ml  \
# 0  Manufacturing/Fabrication        Small          3-4         No
# 1  Manufacturing/Fabrication        Large          1-2  Exploring
#
#      year_salary investment_ml main_bd main_bi  \
# 0  25,000-29,999       100-999     NaN     NaN
# 1  60,000-69,999             0     NaN     NaN
#
# ...

# %%
df = df_adalab.copy()

# %%
df.head(2)
# Out:
#    id_survey  time    age gender    country            studies  \
# 0          0   910  50-54    Man      India  Bachelor’s degree
# 1          1   784  50-54    Man  Indonesia    Master’s degree
#
#                   position years_programming preferred_language  \
# 0                    Other               NaN             Python
# 1  Program/Project Manager               NaN             Python
#
#            computing_platform times_use_tpu years_use_ml  \
# 0                    A laptop     2-5 times         5-10
# 1  A cloud computing platform         Never          < 1
#
#                     industry company_size da_employees company_ml  \
# 0  Manufacturing/Fabrication        Small          3-4         No
# 1  Manufacturing/Fabrication        Large          1-2  Exploring
#
#      year_salary investment_ml main_bd main_bi  \
# 0  25,000-29,999       100-999     NaN     NaN
# 1  60,000-69,999             0     NaN     NaN
#
# ...

# %%
columnas = ['id_survey','programming_languages', 'ide','hardware', 'visualization','ml_tools','ml_algorithm','bd_a','bi','notebooks','computer_vision','nlp','cloud_platforms_a',
'cloud_product_a','data_storage_products_a','ml_products_a','automated_ml_tools_a','ml_experiments_a','sharing','courses','media','cloud_platforms_b','cloud_products_b', 'ml_products_b','bd_b', 'bi_b', 'automated_ml_tools_b', 'regular_automl_b','ml_experiments_b']

# %%
df_explode = df[columnas]

# %%
df_explode.head(2)
# Out:
#    id_survey programming_languages                         ide  \
# 0          0             Python, R                 Vim / Emacs
# 1          1     SQL, C, C++, Java  Notepad++,Jupyter Notebook
#
#             hardware                                      visualization  \
# 0  Google Cloud TPUs  Matplotlib ,Seaborn ,Ggplot / ggplot2 ,Shiny ,...
# 1                NaN                                         Matplotlib
#
#                            ml_tools  \
# 0  Scikit-learn , TensorFlow ,Caret
# 1                      Scikit-learn
#
#                                         ml_algorithm        bd_a   bi  \
# 0  Linear or Logistic Regression, Decision Trees ...  PostgreSQL  NaN
# 1  Linear or Logistic Regression, Decision Trees ...         NaN  NaN
#
#                           notebooks                    computer_vision  \
# 0                   Colab Notebooks  General purpose image/video tools
# 1  Kaggle Notebooks,Colab Notebooks                                NaN
#
# ...

# %%
for col in columnas[1:]:
    df_explode[col] = df_explode[col].str.split(',')
# Out:
# /var/folders/cf/7kf7s8j17wn53znl0ywm912w0000gp/T/ipykernel_3306/2930975392.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_explode[col] = df_explode[col].str.split(',')

# %%
df_explode.head(2)
# Out:
#    id_survey   programming_languages                            ide  \
# 0          0            [Python,  R]                  [Vim / Emacs]
# 1          1  [SQL,  C,  C++,  Java]  [Notepad++, Jupyter Notebook]
#
#               hardware                                      visualization  \
# 0  [Google Cloud TPUs]  [Matplotlib , Seaborn , Ggplot / ggplot2 , Shi...
# 1                  NaN                                       [Matplotlib]
#
#                                ml_tools  \
# 0  [Scikit-learn ,  TensorFlow , Caret]
# 1                        [Scikit-learn]
#
#                                         ml_algorithm          bd_a   bi  \
# 0  [Linear or Logistic Regression,  Decision Tree...  [PostgreSQL]  NaN
# 1  [Linear or Logistic Regression,  Decision Tree...           NaN  NaN
#
#                              notebooks                      computer_vision  \
# 0                    [Colab Notebooks]  [General purpose image/video tools]
# ...

# %%
df_explode.head(2)
# Out:
#    id_survey   programming_languages                            ide  \
# 0          0            [Python,  R]                  [Vim / Emacs]
# 1          1  [SQL,  C,  C++,  Java]  [Notepad++, Jupyter Notebook]
#
#               hardware                                      visualization  \
# 0  [Google Cloud TPUs]  [Matplotlib , Seaborn , Ggplot / ggplot2 , Shi...
# 1                  NaN                                       [Matplotlib]
#
#                                ml_tools  \
# 0  [Scikit-learn ,  TensorFlow , Caret]
# 1                        [Scikit-learn]
#
#                                         ml_algorithm          bd_a   bi  \
# 0  [Linear or Logistic Regression,  Decision Tree...  [PostgreSQL]  NaN
# 1  [Linear or Logistic Regression,  Decision Tree...           NaN  NaN
#
#                              notebooks                      computer_vision  \
# 0                    [Colab Notebooks]  [General purpose image/video tools]
# ...

# %%
def quitar_espacios(elemento):
    '''
    Esta función recoge elemento a elemento de una columna, quita los espacios de los lados y
    devuelve el string modificado'''
    try:
        return elemento.strip()
    except:
        return np.nan

# %%
def explode_strip(dataframe,columna):
    ''' 
    Esta función recoge el dataframe y la columna a modificar. Hace un explode de esa columna y quita los espacios de cada elemento.
    Devuelve el dataframe modificado.'''
    dataframe2 = dataframe.explode(columna)
    dataframe2[columna] = dataframe2[columna].apply(quitar_espacios)
    return dataframe2

# %%
df_prueba = explode_strip(df_explode,'programming_languages')

# %%
df_prueba['programming_languages'].value_counts()
# Out:
# programming_languages
# Python        21860
# SQL           10756
# C++            5535
# R              5334
# Java           4769
# C              4709
# Javascript     4332
# MATLAB         2935
# Other          2575
# Bash           2216
# Julia           305
# Swift           242
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (25973, 53)

# %%
df_explode.shape
# Out:
# (25973, 29)

# %%
for col in columnas[1:]:
    df.drop(col,axis=1,inplace=True)

# %%
df.shape
# Out:
# (25973, 25)

# %%
df.head(2)
# Out:
#    id_survey  time    age gender    country            studies  \
# 0          0   910  50-54    Man      India  Bachelor’s degree
# 1          1   784  50-54    Man  Indonesia    Master’s degree
#
#                   position years_programming preferred_language  \
# 0                    Other               NaN             Python
# 1  Program/Project Manager               NaN             Python
#
#            computing_platform times_use_tpu years_use_ml  \
# 0                    A laptop     2-5 times         5-10
# 1  A cloud computing platform         Never          < 1
#
#                     industry company_size da_employees company_ml  \
# 0  Manufacturing/Fabrication        Small          3-4         No
# 1  Manufacturing/Fabrication        Large          1-2  Exploring
#
#      year_salary investment_ml main_bd main_bi  \
# 0  25,000-29,999       100-999     NaN     NaN
# 1  60,000-69,999             0     NaN     NaN
#
#                           main_da  \
# ...

# %%
df.to_csv('archivos_resultantes/dataframe_graficas.csv')
df_explode.to_csv('archivos_resultantes/dataframe_graficas_explode.csv')
