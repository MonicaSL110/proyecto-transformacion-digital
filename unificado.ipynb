# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn
pd.options.display.max_columns=None
pd.options.display.max_rows=None

# %%
df = pd.read_csv('archivo_unificado.csv')
df.drop('Unnamed: 0', axis = 1, inplace = True)
df.head(1)
# Out:
#    time    age gender     Q3                 Q4     Q5          Q6      Q8  \
# 0   910  50-54    Man  India  Bachelor’s degree  Other  5-10 years  Python
#
#         Q11        Q13         Q15                        Q20  \
# 0  A laptop  2-5 times  5-10 years  Manufacturing/Fabrication
#
#                 Q21  Q22                            Q23            Q25  \
# 0  50-249 employees  3-4  No (we do not use ML methods)  25,000-29,999
#
#          Q26  Q33  Q35                                                Q41  \
# 0  $100-$999  NaN  NaN  Local development environments (RStudio, Jupyt...
#
#           Q7            Q9                 Q12  \
# 0  Python, R   Vim / Emacs  Google Cloud TPUs
#
#                                                  Q14  \
# 0   Matplotlib ,Seaborn ,Ggplot / ggplot2 ,Shiny ...
#
#                                  Q16  \
# 0  Scikit-learn , TensorFlow ,Caret
#
#                                                  Q17  \
# ...

# %%
df.shape
# Out:
# (25973, 258)

# %%
def union_q10 (columna1,columna2,columa3,columna4,columna5,columna6,columna7,columna8,columna9,columna10,columna11,columna12,
            columna13,columna14,columna15,columna16,columna17):
    lista = [columna1,columna2,columa3,columna4,columna5,columna6,columna7,columna8,columna9,columna10,columna11,columna12,
             columna13,columna14,columna15,columna16,columna17]
    lista_str = [str(x) for x in lista]
    lista_final = []
    for i in lista_str:
        if i.lower() not in ['nan']:
            lista_final.append(i)
    texto = ', '.join(lista_final)    
    return texto

# %%
df['Q10'] = df.apply(lambda dataframe: union_q10(dataframe['Q10_Part_1'],dataframe['Q10_Part_2'],dataframe['Q10_Part_3'],dataframe['Q10_Part_4'],
                                          dataframe['Q10_Part_5'],dataframe['Q10_Part_6'],dataframe['Q10_Part_7'],dataframe['Q10_Part_8'],
                                          dataframe['Q10_Part_9'],dataframe['Q10_Part_10'],dataframe['Q10_Part_11'],dataframe['Q10_Part_12'],
                                          dataframe['Q10_Part_13'],dataframe['Q10_Part_14'],dataframe['Q10_Part_15'],dataframe['Q10_Part_16'],
                                          dataframe['Q10_OTHER']), axis = 1)

# %%
df.sample(1)
# Out:
#       time    age gender     Q3  \
# 7804   320  18-21    Man  India
#
#                                                      Q4       Q5         Q6  \
# 7804  Some college/university study without earning ...  Student  1-3 years
#
#           Q8                            Q11        Q13        Q15  Q20  Q21  \
# 7804  Python  A personal computer / desktop  2-5 times  2-3 years  NaN  NaN
#
#       Q22  Q23  Q25  Q26  Q33  Q35  Q41                                 Q7  \
# 7804  NaN  NaN  NaN  NaN  NaN  NaN  NaN  Python, C, C++, Javascript, Other
#
#                                            Q9                   Q12  \
# 7804  Visual Studio Code (VSCode) , Notepad++   NVIDIA GPUs , Other
#
#                 Q14                   Q16  \
# 7804  Shiny , Other  H2O 3 ,Caret , Other
#
#                                                     Q17  Q24  Q32  Q34  \
# 7804  Linear or Logistic Regression, Bayesian Approa...  NaN  NaN  NaN
#
# ...

# %%
df.drop(['Q10_Part_1', 'Q10_Part_2', 'Q10_Part_3', 'Q10_Part_4', 'Q10_Part_5',
       'Q10_Part_6', 'Q10_Part_7', 'Q10_Part_8', 'Q10_Part_9', 'Q10_Part_10',
       'Q10_Part_11', 'Q10_Part_12', 'Q10_Part_13', 'Q10_Part_14',
       'Q10_Part_15', 'Q10_Part_16', 'Q10_OTHER'], axis = 1, inplace = True)
    
df.head(1)
# Out:
#    time    age gender     Q3                 Q4     Q5          Q6      Q8  \
# 0   910  50-54    Man  India  Bachelor’s degree  Other  5-10 years  Python
#
#         Q11        Q13         Q15                        Q20  \
# 0  A laptop  2-5 times  5-10 years  Manufacturing/Fabrication
#
#                 Q21  Q22                            Q23            Q25  \
# 0  50-249 employees  3-4  No (we do not use ML methods)  25,000-29,999
#
#          Q26  Q33  Q35                                                Q41  \
# 0  $100-$999  NaN  NaN  Local development environments (RStudio, Jupyt...
#
#           Q7            Q9                 Q12  \
# 0  Python, R   Vim / Emacs  Google Cloud TPUs
#
#                                                  Q14  \
# 0   Matplotlib ,Seaborn ,Ggplot / ggplot2 ,Shiny ...
#
#                                  Q16  \
# 0  Scikit-learn , TensorFlow ,Caret
#
#                                                  Q17  \
# ...

# %%
df.shape
# Out:
# (25973, 242)

# %%
def union_q18 (columna1,columna2,columa3,columna4,columna5,columna6,columna7):
    lista = [columna1,columna2,columa3,columna4,columna5,columna6,columna7]
    lista_str = [str(x) for x in lista]
    lista_final = []
    for i in lista_str:
        if i.lower() not in ['nan']:
            lista_final.append(i)
    texto = ', '.join(lista_final)    
    return texto

# %%
df['Q18'] = df.apply(lambda dataframe: union_q18(dataframe['Q18_Part_1'],dataframe['Q18_Part_2'],dataframe['Q18_Part_3'],dataframe['Q18_Part_4'],
                                          dataframe['Q18_Part_5'],dataframe['Q18_Part_6'], dataframe['Q18_OTHER']), axis = 1)

# %%
df.drop(['Q18_Part_1', 'Q18_Part_2', 'Q18_Part_3', 'Q18_Part_4', 'Q18_Part_5',
       'Q18_Part_6', 'Q18_OTHER'], axis = 1, inplace = True)

# %%
df.head(1)
# Out:
#    time    age gender     Q3                 Q4     Q5          Q6      Q8  \
# 0   910  50-54    Man  India  Bachelor’s degree  Other  5-10 years  Python
#
#         Q11        Q13         Q15                        Q20  \
# 0  A laptop  2-5 times  5-10 years  Manufacturing/Fabrication
#
#                 Q21  Q22                            Q23            Q25  \
# 0  50-249 employees  3-4  No (we do not use ML methods)  25,000-29,999
#
#          Q26  Q33  Q35                                                Q41  \
# 0  $100-$999  NaN  NaN  Local development environments (RStudio, Jupyt...
#
#           Q7            Q9                 Q12  \
# 0  Python, R   Vim / Emacs  Google Cloud TPUs
#
#                                                  Q14  \
# 0   Matplotlib ,Seaborn ,Ggplot / ggplot2 ,Shiny ...
#
#                                  Q16  \
# 0  Scikit-learn , TensorFlow ,Caret
#
#                                                  Q17  \
# ...

# %%
df.shape
# Out:
# (25973, 236)

# %%
def union_q19 (columna1,columna2,columa3,columna4,columna5,columna6):
    lista = [columna1,columna2,columa3,columna4,columna5,columna6]
    lista_str = [str(x) for x in lista]
    lista_final = []
    for i in lista_str:
        if i.lower() not in ['nan']:
            lista_final.append(i)
    texto = ', '.join(lista_final)    
    return texto

# %%
df['Q19'] = df.apply(lambda dataframe: union_q19(dataframe['Q19_Part_1'],dataframe['Q19_Part_2'],dataframe['Q19_Part_3'],dataframe['Q19_Part_4'],
                                          dataframe['Q19_Part_5'], dataframe['Q19_OTHER']), axis = 1)

# %%
df.drop(['Q19_Part_1', 'Q19_Part_2', 'Q19_Part_3', 'Q19_Part_4', 'Q19_Part_5',
       'Q19_OTHER'], axis = 1, inplace = True)

# %%
df.shape
# Out:
# (25973, 231)

# %%
def union_q27A (columna1,columna2,columa3,columna4,columna5,columna6,columna7,columna8,columna9,columna10,columna11,columna12):
    lista = [columna1,columna2,columa3,columna4,columna5,columna6,columna7,columna8,columna9,columna10,columna11,columna12]
    lista_str = [str(x) for x in lista]
    lista_final = []
    for i in lista_str:
        if i.lower() not in ['nan']:
            lista_final.append(i)
    texto = ', '.join(lista_final)    
    return texto

# %%
df['Q27-A'] = df.apply(lambda dataframe: union_q27A(dataframe['Q27_A_Part_1'],dataframe['Q27_A_Part_2'],dataframe['Q27_A_Part_3'],
                                                    dataframe['Q27_A_Part_4'], dataframe['Q27_A_Part_5'], dataframe['Q27_A_Part_6'],
                                                    dataframe['Q27_A_Part_7'], dataframe['Q27_A_Part_8'], dataframe['Q27_A_Part_9'],
                                                    dataframe['Q27_A_Part_10'], dataframe['Q27_A_Part_11'], dataframe['Q27_A_OTHER']), axis = 1)

# %%
df.drop(['Q27_A_Part_1', 'Q27_A_Part_2', 'Q27_A_Part_3', 'Q27_A_Part_4', 'Q27_A_Part_5', 
        'Q27_A_Part_6', 'Q27_A_Part_7', 'Q27_A_Part_8', 'Q27_A_Part_9', 'Q27_A_Part_10', 'Q27_A_Part_11', 'Q27_A_OTHER'], 
        axis = 1, inplace = True)

# %%
df.shape
# Out:
# (25973, 220)

# %%
def union_q29A (columna1,columna2,columa3,columna4,columna5):
    lista = [columna1,columna2,columa3,columna4,columna5]
    lista_str = [str(x) for x in lista]
    lista_final = []
    for i in lista_str:
        if i.lower() not in ['nan']:
            lista_final.append(i)
    texto = ', '.join(lista_final)    
    return texto

# %%
df['Q29-A'] = df.apply(lambda dataframe: union_q29A(dataframe['Q29_A_Part_1'],dataframe['Q29_A_Part_2'],dataframe['Q29_A_Part_3'],
                                                    dataframe['Q29_A_Part_4'], dataframe['Q29_A_OTHER']), axis = 1)

# %%
df.drop(['Q29_A_Part_1', 'Q29_A_Part_2', 'Q29_A_Part_3', 'Q29_A_Part_4',
       'Q29_A_OTHER'], axis = 1, inplace = True)

# %%
df.shape
# Out:
# (25973, 216)

# %%
def union_q30A (columna1,columna2,columa3,columna4,columna5, columna6, columna7, columna8):
    lista = [columna1,columna2,columa3,columna4,columna5, columna6, columna7, columna8]
    lista_str = [str(x) for x in lista]
    lista_final = []
    for i in lista_str:
        if i.lower() not in ['nan']:
            lista_final.append(i)
    texto = ', '.join(lista_final)    
    return texto

# %%
df['Q30-A'] = df.apply(lambda dataframe: union_q30A(dataframe['Q30_A_Part_1'],dataframe['Q30_A_Part_2'],dataframe['Q30_A_Part_3'],
                                                    dataframe['Q30_A_Part_4'], dataframe['Q30_A_Part_5'], dataframe['Q30_A_Part_6'],
                                                     dataframe['Q30_A_Part_7'], dataframe['Q30_A_OTHER']), axis = 1)

# %%
df.drop(['Q30_A_Part_1', 'Q30_A_Part_2', 'Q30_A_Part_3', 'Q30_A_Part_4',
       'Q30_A_Part_5', 'Q30_A_Part_6', 'Q30_A_Part_7', 'Q30_A_OTHER'], axis = 1, inplace = True)

# %%
df.shape
# Out:
# (25973, 209)

# %%
def union_q31A (columna1,columna2,columa3,columna4,columna5, columna6, columna7, columna8, columna9, columna10):
    lista = [columna1,columna2,columa3,columna4,columna5, columna6, columna7, columna8, columna9, columna10]
    lista_str = [str(x) for x in lista]
    lista_final = []
    for i in lista_str:
        if i.lower() not in ['nan']:
            lista_final.append(i)
    texto = ', '.join(lista_final)    
    return texto

# %%
df['Q31-A'] = df.apply(lambda dataframe: union_q31A(dataframe['Q31_A_Part_1'],dataframe['Q31_A_Part_2'],dataframe['Q31_A_Part_3'],
                                                    dataframe['Q31_A_Part_4'], dataframe['Q31_A_Part_5'], dataframe['Q31_A_Part_6'],
                                                     dataframe['Q31_A_Part_7'], dataframe['Q31_A_Part_8'],dataframe['Q31_A_Part_9'], 
                                                     dataframe['Q31_A_OTHER']), axis = 1)

# %%
df.drop(['Q31_A_Part_1', 'Q31_A_Part_2', 'Q31_A_Part_3', 'Q31_A_Part_4',
       'Q31_A_Part_5', 'Q31_A_Part_6', 'Q31_A_Part_7', 'Q31_A_Part_8',
       'Q31_A_Part_9', 'Q31_A_OTHER'], axis = 1, inplace = True)

# %%
df.shape
# Out:
# (25973, 200)

# %%
def union_q36A (columna1,columna2,columa3,columna4,columna5, columna6, columna7, columna8):
    lista = [columna1,columna2,columa3,columna4,columna5, columna6, columna7, columna8]
    lista_str = [str(x) for x in lista]
    lista_final = []
    for i in lista_str:
        if i.lower() not in ['nan']:
            lista_final.append(i)
    texto = ', '.join(lista_final)    
    return texto

# %%
df['Q36-A'] = df.apply(lambda dataframe: union_q36A(dataframe['Q36_A_Part_1'],dataframe['Q36_A_Part_2'],dataframe['Q36_A_Part_3'],
                                                    dataframe['Q36_A_Part_4'], dataframe['Q36_A_Part_5'], dataframe['Q36_A_Part_6'],
                                                     dataframe['Q36_A_Part_7'], dataframe['Q36_A_OTHER']), axis = 1)

# %%
df.drop(['Q36_A_Part_1', 'Q36_A_Part_2', 'Q36_A_Part_3', 'Q36_A_Part_4',
       'Q36_A_Part_5', 'Q36_A_Part_6', 'Q36_A_Part_7', 'Q36_A_OTHER'], axis = 1, inplace = True)

# %%
df.shape
# Out:
# (25973, 193)

# %%
def union_q37A (columna1,columna2,columa3,columna4,columna5, columna6, columna7, columna8):
    lista = [columna1,columna2,columa3,columna4,columna5, columna6, columna7, columna8]
    lista_str = [str(x) for x in lista]
    lista_final = []
    for i in lista_str:
        if i.lower() not in ['nan']:
            lista_final.append(i)
    texto = ', '.join(lista_final)    
    return texto

# %%
df['Q37-A'] = df.apply(lambda dataframe: union_q37A(dataframe['Q37_A_Part_1'],dataframe['Q37_A_Part_2'],dataframe['Q37_A_Part_3'],
                                                    dataframe['Q37_A_Part_4'], dataframe['Q37_A_Part_5'], dataframe['Q37_A_Part_6'],
                                                     dataframe['Q37_A_Part_7'], dataframe['Q37_A_OTHER']), axis = 1)

# %%
df.drop(['Q37_A_Part_1', 'Q37_A_Part_2', 'Q37_A_Part_3', 'Q37_A_Part_4',
       'Q37_A_Part_5', 'Q37_A_Part_6', 'Q37_A_Part_7', 'Q37_A_OTHER'], axis = 1, inplace = True)

# %%
df.shape
# Out:
# (25973, 186)

# %%
def union_q38A (columna1,columna2,columa3,columna4,columna5,columna6,columna7,columna8,columna9,columna10,columna11,columna12):
    lista = [columna1,columna2,columa3,columna4,columna5,columna6,columna7,columna8,columna9,columna10,columna11,columna12]
    lista_str = [str(x) for x in lista]
    lista_final = []
    for i in lista_str:
        if i.lower() not in ['nan']:
            lista_final.append(i)
    texto = ', '.join(lista_final)    
    return texto

# %%
df['Q38-A'] = df.apply(lambda dataframe: union_q38A(dataframe['Q38_A_Part_1'],dataframe['Q38_A_Part_2'],dataframe['Q38_A_Part_3'],
                                                    dataframe['Q38_A_Part_4'], dataframe['Q38_A_Part_5'], dataframe['Q38_A_Part_6'],
                                                    dataframe['Q38_A_Part_7'], dataframe['Q38_A_Part_8'], dataframe['Q38_A_Part_9'],
                                                    dataframe['Q38_A_Part_10'], dataframe['Q38_A_Part_11'], dataframe['Q38_A_OTHER']), axis = 1)

# %%
df.drop(['Q38_A_Part_1', 'Q38_A_Part_2', 'Q38_A_Part_3', 'Q38_A_Part_4',
       'Q38_A_Part_5', 'Q38_A_Part_6', 'Q38_A_Part_7', 'Q38_A_Part_8',
       'Q38_A_Part_9', 'Q38_A_Part_10', 'Q38_A_Part_11', 'Q38_A_OTHER'], axis = 1, inplace = True)

# %%
df.shape
# Out:
# (25973, 175)

# %%
def union_q39 (columna1,columna2,columa3,columna4,columna5,columna6,columna7,columna8,columna9,columna10):
    lista = [columna1,columna2,columa3,columna4,columna5,columna6,columna7,columna8,columna9,columna10]
    lista_str = [str(x) for x in lista]
    lista_final = []
    for i in lista_str:
        if i.lower() not in ['nan']:
            lista_final.append(i)
    texto = ', '.join(lista_final)    
    return texto

# %%
df['Q39'] = df.apply(lambda dataframe: union_q39(dataframe['Q39_Part_1'],dataframe['Q39_Part_2'],dataframe['Q39_Part_3'],
                                                    dataframe['Q39_Part_4'], dataframe['Q39_Part_5'], dataframe['Q39_Part_6'],
                                                    dataframe['Q39_Part_7'], dataframe['Q39_Part_8'], dataframe['Q39_Part_9'],
                                                    dataframe['Q39_OTHER']), axis = 1)

# %%
df.drop(['Q39_Part_1', 'Q39_Part_2', 'Q39_Part_3', 'Q39_Part_4', 'Q39_Part_5',
       'Q39_Part_6', 'Q39_Part_7', 'Q39_Part_8', 'Q39_Part_9', 'Q39_OTHER'], axis = 1, inplace = True)

# %%
df.shape
# Out:
# (25973, 166)

# %%
def union_q40 (columna1,columna2,columa3,columna4,columna5,columna6,columna7,columna8,columna9,columna10,columna11,columna12):
    lista = [columna1,columna2,columa3,columna4,columna5,columna6,columna7,columna8,columna9,columna10,columna11,columna12]
    lista_str = [str(x) for x in lista]
    lista_final = []
    for i in lista_str:
        if i.lower() not in ['nan']:
            lista_final.append(i)
    texto = ', '.join(lista_final)    
    return texto

# %%
df['Q40'] = df.apply(lambda dataframe: union_q40(dataframe['Q40_Part_1'],dataframe['Q40_Part_2'],dataframe['Q40_Part_3'],
                                                    dataframe['Q40_Part_4'], dataframe['Q40_Part_5'], dataframe['Q40_Part_6'],
                                                    dataframe['Q40_Part_7'], dataframe['Q40_Part_8'], dataframe['Q40_Part_9'],
                                                    dataframe['Q40_Part_10'], dataframe['Q40_Part_11'], dataframe['Q40_OTHER']), axis = 1)

# %%
df.drop(['Q40_Part_1', 'Q40_Part_2', 'Q40_Part_3', 'Q40_Part_4', 'Q40_Part_5',
      'Q40_Part_6', 'Q40_Part_7', 'Q40_Part_8', 'Q40_Part_9', 'Q40_Part_10', 'Q40_Part_11', 'Q40_OTHER'], axis = 1, inplace = True)

# %%
df.shape
# Out:
# (25973, 155)

# %%
def union_q42 (columna1,columna2,columa3,columna4,columna5,columna6,columna7,columna8,columna9,columna10,columna11,columna12):
    lista = [columna1,columna2,columa3,columna4,columna5,columna6,columna7,columna8,columna9,columna10,columna11,columna12]
    lista_str = [str(x) for x in lista]
    lista_final = []
    for i in lista_str:
        if i.lower() not in ['nan']:
            lista_final.append(i)
    texto = ', '.join(lista_final)    
    return texto

# %%
df['Q42'] = df.apply(lambda dataframe: union_q42(dataframe['Q42_Part_1'],dataframe['Q42_Part_2'],dataframe['Q42_Part_3'],
                                                    dataframe['Q42_Part_4'], dataframe['Q42_Part_5'], dataframe['Q42_Part_6'],
                                                    dataframe['Q42_Part_7'], dataframe['Q42_Part_8'], dataframe['Q42_Part_9'],
                                                    dataframe['Q42_Part_10'], dataframe['Q42_Part_11'], dataframe['Q42_OTHER']), axis = 1)

# %%
df.drop(['Q42_Part_1', 'Q42_Part_2', 'Q42_Part_3', 'Q42_Part_4', 'Q42_Part_5',
       'Q42_Part_6', 'Q42_Part_7', 'Q42_Part_8', 'Q42_Part_9', 'Q42_Part_10', 'Q42_Part_11', 'Q42_OTHER'], axis = 1, inplace = True)

# %%
df.shape
# Out:
# (25973, 144)

# %%
def union_q27B (columna1,columna2,columa3,columna4,columna5,columna6,columna7,columna8,columna9,columna10,columna11,columna12):
    lista = [columna1,columna2,columa3,columna4,columna5,columna6,columna7,columna8,columna9,columna10,columna11,columna12]
    lista_str = [str(x) for x in lista]
    lista_final = []
    for i in lista_str:
        if i.lower() not in ['nan']:
            lista_final.append(i)
    texto = ', '.join(lista_final)    
    return texto

# %%
df['Q27-B'] = df.apply(lambda dataframe: union_q27B(dataframe['Q27_B_Part_1'],dataframe['Q27_B_Part_2'],dataframe['Q27_B_Part_3'],
                                                    dataframe['Q27_B_Part_4'], dataframe['Q27_B_Part_5'], dataframe['Q27_B_Part_6'],
                                                    dataframe['Q27_B_Part_7'], dataframe['Q27_B_Part_8'], dataframe['Q27_B_Part_9'],
                                                    dataframe['Q27_B_Part_10'], dataframe['Q27_B_Part_11'], dataframe['Q27_B_OTHER']), axis = 1)

# %%
df.drop(['Q27_B_Part_1', 'Q27_B_Part_2', 'Q27_B_Part_3', 'Q27_B_Part_4',
       'Q27_B_Part_5', 'Q27_B_Part_6', 'Q27_B_Part_7', 'Q27_B_Part_8',
       'Q27_B_Part_9', 'Q27_B_Part_10','Q27_B_Part_11', 'Q27_B_OTHER'], axis = 1, inplace = True)

# %%
df.shape
# Out:
# (25973, 133)

# %%
def union_q29B (columna1,columna2,columa3,columna4,columna5):
    lista = [columna1,columna2,columa3,columna4,columna5]
    lista_str = [str(x) for x in lista]
    lista_final = []
    for i in lista_str:
        if i.lower() not in ['nan']:
            lista_final.append(i)
    texto = ', '.join(lista_final)    
    return texto

# %%
df['Q29-B'] = df.apply(lambda dataframe: union_q29B(dataframe['Q29_B_Part_1'],dataframe['Q29_B_Part_2'],dataframe['Q29_B_Part_3'],
                                                    dataframe['Q29_B_Part_4'], dataframe['Q29_B_OTHER']), axis = 1)

# %%
df.drop(['Q29_B_Part_1', 'Q29_B_Part_2', 'Q29_B_Part_3', 'Q29_B_Part_4',
       'Q29_B_OTHER'], axis = 1, inplace = True)

# %%
df.shape
# Out:
# (25973, 129)

# %%
def union_q30B (columna1,columna2,columa3,columna4,columna5, columna6, columna7, columna8):
    lista = [columna1,columna2,columa3,columna4,columna5, columna6, columna7, columna8]
    lista_str = [str(x) for x in lista]
    lista_final = []
    for i in lista_str:
        if i.lower() not in ['nan']:
            lista_final.append(i)
    texto = ', '.join(lista_final)    
    return texto

# %%
df['Q30-B'] = df.apply(lambda dataframe: union_q30B(dataframe['Q30_B_Part_1'],dataframe['Q30_B_Part_2'],dataframe['Q30_B_Part_3'],
                                                    dataframe['Q30_B_Part_4'], dataframe['Q30_B_Part_5'], dataframe['Q30_B_Part_6'],
                                                     dataframe['Q30_B_Part_7'], dataframe['Q30_B_OTHER']), axis = 1)

# %%
df.drop(['Q30_B_Part_1', 'Q30_B_Part_2', 'Q30_B_Part_3', 'Q30_B_Part_4',
       'Q30_B_Part_5', 'Q30_B_Part_6', 'Q30_B_Part_7', 'Q30_B_OTHER'], axis = 1, inplace = True)

# %%
df.shape
# Out:
# (25973, 122)

# %%
def union_q31B (columna1,columna2,columa3,columna4,columna5, columna6, columna7, columna8, columna9, columna10):
    lista = [columna1,columna2,columa3,columna4,columna5, columna6, columna7, columna8, columna9, columna10]
    lista_str = [str(x) for x in lista]
    lista_final = []
    for i in lista_str:
        if i.lower() not in ['nan']:
            lista_final.append(i)
    texto = ', '.join(lista_final)    
    return texto

# %%
df['Q31-B'] = df.apply(lambda dataframe: union_q31B(dataframe['Q31_B_Part_1'],dataframe['Q31_B_Part_2'],dataframe['Q31_B_Part_3'],
                                                    dataframe['Q31_B_Part_4'], dataframe['Q31_B_Part_5'], dataframe['Q31_B_Part_6'],
                                                     dataframe['Q31_B_Part_7'], dataframe['Q31_B_Part_8'],dataframe['Q31_B_Part_9'], 
                                                     dataframe['Q31_B_OTHER']), axis = 1)

# %%
df.drop(['Q31_B_Part_1', 'Q31_B_Part_2', 'Q31_B_Part_3', 'Q31_B_Part_4',
       'Q31_B_Part_5', 'Q31_B_Part_6', 'Q31_B_Part_7', 'Q31_B_Part_8',
       'Q31_B_Part_9', 'Q31_B_OTHER'], axis = 1, inplace = True)

# %%
def union_q32B (columna1,columna2,columa3,columna4,columna5,columna6,columna7,columna8,columna9,columna10,columna11,columna12,
                columna13, columna14, columna15, columna16, columna17, columna18, columna19, columna20, columna21):
    lista = [columna1,columna2,columa3,columna4,columna5,columna6,columna7,columna8,columna9,columna10,columna11,columna12,
             columna13, columna14, columna15, columna16, columna17, columna18, columna19, columna20, columna21]
    lista_str = [str(x) for x in lista]
    lista_final = []
    for i in lista_str:
        if i.lower() not in ['nan']:
            lista_final.append(i)
    texto = ', '.join(lista_final)    
    return texto

# %%
df['Q32-B'] = df.apply(lambda dataframe: union_q32B(dataframe['Q32_B_Part_1'],dataframe['Q32_B_Part_2'],dataframe['Q32_B_Part_3'],
                                                    dataframe['Q32_B_Part_4'], dataframe['Q32_B_Part_5'], dataframe['Q32_B_Part_6'],
                                                    dataframe['Q32_B_Part_7'], dataframe['Q32_B_Part_8'], dataframe['Q32_B_Part_9'],
                                                    dataframe['Q32_B_Part_10'], dataframe['Q32_B_Part_11'], dataframe['Q32_B_Part_12'],
                                                    dataframe['Q32_B_Part_13'], dataframe['Q32_B_Part_14'], dataframe['Q32_B_Part_15'],
                                                    dataframe['Q32_B_Part_16'], dataframe['Q32_B_Part_17'], dataframe['Q32_B_Part_18'],
                                                    dataframe['Q32_B_Part_19'], dataframe['Q32_B_Part_20'], dataframe['Q32_B_OTHER']), axis = 1)

# %%
df.drop(['Q32_B_Part_1', 'Q32_B_Part_2', 'Q32_B_Part_3', 'Q32_B_Part_4',
       'Q32_B_Part_5', 'Q32_B_Part_6', 'Q32_B_Part_7', 'Q32_B_Part_8',
       'Q32_B_Part_9', 'Q32_B_Part_10', 'Q32_B_Part_11', 'Q32_B_Part_12',
       'Q32_B_Part_13', 'Q32_B_Part_14', 'Q32_B_Part_15', 'Q32_B_Part_16',
       'Q32_B_Part_17', 'Q32_B_Part_18', 'Q32_B_Part_19', 'Q32_B_Part_20',
       'Q32_B_OTHER'], axis = 1, inplace = True)

# %%
df.shape
# Out:
# (25973, 93)

# %%
def union_q34B (columna1,columna2,columa3,columna4,columna5,columna6,columna7,columna8,columna9,columna10,columna11,columna12,
                columna13, columna14, columna15, columna16, columna17):
    lista = [columna1,columna2,columa3,columna4,columna5,columna6,columna7,columna8,columna9,columna10,columna11,columna12,
             columna13, columna14, columna15, columna16, columna17]
    lista_str = [str(x) for x in lista]
    lista_final = []
    for i in lista_str:
        if i.lower() not in ['nan']:
            lista_final.append(i)
    texto = ', '.join(lista_final)    
    return texto

# %%
df['Q34-B'] = df.apply(lambda dataframe: union_q34B(dataframe['Q34_B_Part_1'], dataframe['Q34_B_Part_2'], dataframe['Q34_B_Part_3'],
                                                    dataframe['Q34_B_Part_4'], dataframe['Q34_B_Part_5'], dataframe['Q34_B_Part_6'],
                                                    dataframe['Q34_B_Part_7'], dataframe['Q34_B_Part_8'], dataframe['Q34_B_Part_9'],
                                                    dataframe['Q34_B_Part_10'], dataframe['Q34_B_Part_11'], dataframe['Q34_B_Part_12'],
                                                    dataframe['Q34_B_Part_13'], dataframe['Q34_B_Part_14'], dataframe['Q34_B_Part_15'],
                                                    dataframe['Q34_B_Part_16'], dataframe['Q34_B_OTHER']), axis = 1)

# %%
df.drop(['Q34_B_Part_1', 'Q34_B_Part_2', 'Q34_B_Part_3', 'Q34_B_Part_4',
       'Q34_B_Part_5', 'Q34_B_Part_6', 'Q34_B_Part_7', 'Q34_B_Part_8',
       'Q34_B_Part_9', 'Q34_B_Part_10', 'Q34_B_Part_11', 'Q34_B_Part_12',
       'Q34_B_Part_13', 'Q34_B_Part_14', 'Q34_B_Part_15', 'Q34_B_Part_16',
       'Q34_B_OTHER'], axis = 1, inplace = True)

# %%
df.shape
# Out:
# (25973, 77)

# %%
def union_q36B (columna1,columna2,columa3,columna4,columna5, columna6, columna7, columna8):
    lista = [columna1,columna2,columa3,columna4,columna5, columna6, columna7, columna8]
    lista_str = [str(x) for x in lista]
    lista_final = []
    for i in lista_str:
        if i.lower() not in ['nan']:
            lista_final.append(i)
    texto = ', '.join(lista_final)    
    return texto

# %%
df['Q36-B'] = df.apply(lambda dataframe: union_q36B(dataframe['Q36_B_Part_1'],dataframe['Q36_B_Part_2'],dataframe['Q36_B_Part_3'],
                                                    dataframe['Q36_B_Part_4'], dataframe['Q36_B_Part_5'], dataframe['Q36_B_Part_6'],
                                                     dataframe['Q36_B_Part_7'], dataframe['Q36_B_OTHER']), axis = 1)

# %%
df.drop(['Q36_B_Part_1', 'Q36_B_Part_2', 'Q36_B_Part_3', 'Q36_B_Part_4',
       'Q36_B_Part_5', 'Q36_B_Part_6', 'Q36_B_Part_7', 'Q36_B_OTHER'], axis = 1, inplace = True)

# %%
df.shape
# Out:
# (25973, 70)

# %%
def union_q37B (columna1,columna2,columa3,columna4,columna5, columna6, columna7, columna8):
    lista = [columna1,columna2,columa3,columna4,columna5, columna6, columna7, columna8]
    lista_str = [str(x) for x in lista]
    lista_final = []
    for i in lista_str:
        if i.lower() not in ['nan']:
            lista_final.append(i)
    texto = ', '.join(lista_final)    
    return texto

# %%
df['Q37-B'] = df.apply(lambda dataframe: union_q37B(dataframe['Q37_B_Part_1'],dataframe['Q37_B_Part_2'],dataframe['Q37_B_Part_3'],
                                                    dataframe['Q37_B_Part_4'], dataframe['Q37_B_Part_5'], dataframe['Q37_B_Part_6'],
                                                     dataframe['Q37_B_Part_7'], dataframe['Q37_B_OTHER']), axis = 1)

# %%
df.drop(['Q37_B_Part_1', 'Q37_B_Part_2', 'Q37_B_Part_3', 'Q37_B_Part_4',
       'Q37_B_Part_5', 'Q37_B_Part_6', 'Q37_B_Part_7', 'Q37_B_OTHER'], axis = 1, inplace = True)

# %%
df.shape
# Out:
# (25973, 63)

# %%
def union_q38B (columna1,columna2,columa3,columna4,columna5,columna6,columna7,columna8,columna9,columna10,columna11,columna12):
    lista = [columna1,columna2,columa3,columna4,columna5,columna6,columna7,columna8,columna9,columna10,columna11,columna12]
    lista_str = [str(x) for x in lista]
    lista_final = []
    for i in lista_str:
        if i.lower() not in ['nan']:
            lista_final.append(i)
    texto = ', '.join(lista_final)    
    return texto

# %%
df['Q38-B'] = df.apply(lambda dataframe: union_q38B(dataframe['Q38_B_Part_1'],dataframe['Q38_B_Part_2'],dataframe['Q38_B_Part_3'],
                                                    dataframe['Q38_B_Part_4'], dataframe['Q38_B_Part_5'], dataframe['Q38_B_Part_6'],
                                                    dataframe['Q38_B_Part_7'], dataframe['Q38_B_Part_8'], dataframe['Q38_B_Part_9'],
                                                    dataframe['Q38_B_Part_10'], dataframe['Q38_B_Part_11'], dataframe['Q38_B_OTHER']), axis = 1)

# %%
df.drop(['Q38_B_Part_1', 'Q38_B_Part_2', 'Q38_B_Part_3', 'Q38_B_Part_4',
       'Q38_B_Part_5', 'Q38_B_Part_6', 'Q38_B_Part_7', 'Q38_B_Part_8',
       'Q38_B_Part_9', 'Q38_B_Part_10', 'Q38_B_Part_11', 'Q38_B_OTHER'], axis = 1, inplace = True)

# %%
df.shape
# Out:
# (25973, 51)

# %%
df.head(1)
# Out:
#    time    age gender     Q3                 Q4     Q5          Q6      Q8  \
# 0   910  50-54    Man  India  Bachelor’s degree  Other  5-10 years  Python
#
#         Q11        Q13         Q15                        Q20  \
# 0  A laptop  2-5 times  5-10 years  Manufacturing/Fabrication
#
#                 Q21  Q22                            Q23            Q25  \
# 0  50-249 employees  3-4  No (we do not use ML methods)  25,000-29,999
#
#          Q26  Q33  Q35                                                Q41  \
# 0  $100-$999  NaN  NaN  Local development environments (RStudio, Jupyt...
#
#           Q7            Q9                 Q12  \
# 0  Python, R   Vim / Emacs  Google Cloud TPUs
#
#                                                  Q14  \
# 0   Matplotlib ,Seaborn ,Ggplot / ggplot2 ,Shiny ...
#
#                                  Q16  \
# 0  Scikit-learn , TensorFlow ,Caret
#
#                                                  Q17  \
# ...
