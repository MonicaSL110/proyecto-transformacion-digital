# %%
import pandas as pd
import numpy as np
pd.options.display.max_columns=None

# %%
df_adalab = pd.read_pickle('archivos_resultantes/archivo_unificado_limpio.pkl')
df_adalab.head()
# Out:
#    id_survey  time    age gender    country            studies  \
# 0          0   910  50-54    Man      India  Bachelor’s degree
# 1          1   784  50-54    Man  Indonesia    Master’s degree
# 2          2   924  22-24    Man   Pakistan    Master’s degree
# 3          3   575  45-49    Man     Mexico    Doctoral degree
# 4          4   781  45-49    Man      India    Doctoral degree
#
#                   position years_programming preferred_language  \
# 0                    Other            Senior             Python
# 1  Program/Project Manager         Architect             Python
# 2        Software Engineer            Junior             Python
# 3       Research Scientist         Architect             Python
# 4                    Other            Junior             Python
#
#            computing_platform times_use_tpu years_use_ml  \
# 0                    A laptop     2-5 times         5-10
# 1  A cloud computing platform         Never          < 1
# ...

# %%
df_adalab.shape
# Out:
# (25973, 53)

# %%
df_adalab = df_adalab[df_adalab["position"].isin(['Data Analyst','Business Analyst'])]
df_adalab = df_adalab[df_adalab["country"].isin(['Spain','France','Russia','Italy','Ukraine','Portugal','Greece','Ireland','Switzerland','Belgium','Belarus','Czech Republic','Romania','Austria', 'Poland','Denmark','Norway','United Kingdom of Great Britain and Northern Ireland','Germany','Turkey','Netherlands','Sweden'])]

# %%
df_adalab.shape
# Out:
# (557, 53)

# %%
df = df_adalab.copy()

# %%
df.head(2)
# Out:
#      id_survey  time    age gender  country            studies  \
# 16          16  1315  50-54    Man  Belgium  Bachelor’s degree
# 167        167  3089  45-49    Man  Austria    Master’s degree
#
#              position years_programming preferred_language computing_platform  \
# 16       Data Analyst         Architect             Python           A laptop
# 167  Business Analyst            Senior                SQL           A laptop
#
#     times_use_tpu years_use_ml                   industry company_size  \
# 16          Never          1-2              Energy/Mining        Large
# 167         Never          < 1  Insurance/Risk Assessment       Medium
#
#     da_employees company_ml      year_salary investment_ml  main_bd  \
# 16           5-9  Exploring      2,000-2,999             0  unknown
# 167          3-4         No  125,000-149,999          1-99  IBM Db2
#
#                 main_bi                         main_da  \
# ...

# %%
columnas = ['id_survey','programming_languages', 'ide','hardware', 'visualization','ml_tools','ml_algorithm','bd_a','bi','notebooks','computer_vision','nlp','cloud_platforms_a',
'cloud_product_a','data_storage_products_a','ml_products_a','automated_ml_tools_a','ml_experiments_a','sharing','courses','media','cloud_platforms_b','cloud_products_b', 'ml_products_b','bd_b', 'bi_b', 'automated_ml_tools_b', 'regular_automl_b','ml_experiments_b']

# %%
df_explode = df[columnas]

# %%
df_explode.head(2)
# Out:
#      id_survey    programming_languages                                  ide  \
# 16          16              Python, SQL           Jupyter  ,Jupyter Notebook
# 167        167  Python, SQL, Javascript  Jupyter  ,PyCharm ,Jupyter Notebook
#
#     hardware                                      visualization      ml_tools  \
# 16      None       Matplotlib ,Seaborn ,Plotly / Plotly Express  Scikit-learn
# 167     None  Matplotlib ,Seaborn ,Plotly / Plotly Express ,...  Scikit-learn
#
#                       ml_algorithm  \
# 16   Linear or Logistic Regression
# 167  Linear or Logistic Regression
#
#                                                   bd_a  \
# 16                                             unknown
# 167  MySQL , PostgreSQL , SQLite , Oracle Database ...
#
#                               bi  \
# 16                       unknown
# 167  Google Data Studio, Tableau
#
#                                              notebooks computer_vision  \
# ...

# %%
for col in columnas[1:]:
    df_explode[col] = df_explode[col].str.split(',')
# Out:
# /var/folders/cf/7kf7s8j17wn53znl0ywm912w0000gp/T/ipykernel_9476/2930975392.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_explode[col] = df_explode[col].str.split(',')

# %%
df_explode.head(2)
# Out:
#      id_survey        programming_languages  \
# 16          16               [Python,  SQL]
# 167        167  [Python,  SQL,  Javascript]
#
#                                          ide hardware  \
# 16             [Jupyter  , Jupyter Notebook]   [None]
# 167  [Jupyter  , PyCharm , Jupyter Notebook]   [None]
#
#                                          visualization        ml_tools  \
# 16    [Matplotlib , Seaborn , Plotly / Plotly Express]  [Scikit-learn]
# 167  [Matplotlib , Seaborn , Plotly / Plotly Expres...  [Scikit-learn]
#
#                         ml_algorithm  \
# 16   [Linear or Logistic Regression]
# 167  [Linear or Logistic Regression]
#
#                                                   bd_a  \
# 16                                           [unknown]
# 167  [MySQL ,  PostgreSQL ,  SQLite ,  Oracle Datab...
#
#                                  bi  \
# 16                        [unknown]
# 167  [Google Data Studio,  Tableau]
#
# ...

# %%
for col in columnas[1:]:
    df.drop(col,axis=1,inplace=True)

# %%
df.shape
# Out:
# (557, 25)

# %%
df_explode.shape
# Out:
# (557, 29)

# %%
df.to_pickle('archivos_resultantes/dataframe_graficas.pkl')
df_explode.to_pickle('archivos_resultantes/dataframe_graficas_explode.pkl')
